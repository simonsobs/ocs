# %%
from spt3g import core
import matplotlib.pyplot as plt

# %%
filename = "2018-07-30_T_19:26:14.g3"
filename = "2018-07-30_T_19:35:42.g3"
file = core.G3File(filename)

data = {}
for frame in file:
    therms = frame["TODs"].keys()
    for therm in therms:
        data.setdefault(therm, [[],[]])
        data[therm][1] += list(frame["TODs"][therm])
        data[therm][0] += list(frame["Timestamps"][therm])

# %%
plt.plot(data["thermA"][0], data["thermA"][1])
plt.show()
